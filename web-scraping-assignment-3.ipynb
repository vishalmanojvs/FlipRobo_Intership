# %% [markdown]
# # 1. Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
# Importing librabries
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https://www.amazon.in/'
driver.get(url)

# %%
# Searching for the place to give the product name
search_job=driver.find_elements(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')

# %%
# Entering the product name required for search
product=input(str('Enter the product name you wish to search for: '))
# Out:
# Enter the product name you wish to search for: guitar

# %%
# Entering the product in searching tab
search_job[0].send_keys(product)

# %%
# Clicking the search button
search=driver.find_elements(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')

# %%
search[0].click()

# %% [markdown]
# # 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
pd=[]
url=driver.find_elements(By.XPATH,"//h2/a[@href]")
for i in url:
    pd.append(i.get_attribute('href'))

# %%
len(pd)
# Out:
# 64

# %%
p=[]
for i in pd[0:4]:
    driver.get(i)
    time.sleep(5)
    try:
        d=driver.find_elements(By.XPATH,"//h1")
        p.append(d[0].text)
    except:
        p.append('Nan')

# %%
p=driver.find_elements(By.XPATH,"//h2/a[@class='a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal']")

# %%
p[0].text
# Out:
# ''

# %%
f=pd.DataFrame(list(zip(p,rat,e)),
               columns =['Product Name', 'Rate','Expected Time'])

# %% [markdown]
# # 3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https://www.google.in/'
driver.get(url)

# %%
# Searching for the place to give the product name
search_job=driver.find_elements(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')

# %%
# Entering the product in searching tab
search_job[0].send_keys('fruits')

# %%
# Pressing Enter for searching
from selenium.webdriver.common.keys import Keys
search_job[0].send_keys(Keys.ENTER)

# %%
sim=driver.find_elements(By.XPATH,'/html/body/div[7]/div/div[4]/div/div[1]/div/div[1]/div/div[2]/a')

# %%
sim[0].click()

# %%
s=driver.find_elements(By.XPATH,'//body//a[1]/div[1]/img')

# %%
import os
import urllib

# %%
u=[]
for i in s:
    image=i.get_attribute("src")
    u.append(image)

# %%
from selenium.common.exceptions import StaleElementReferenceException, NoSuchCookieException
for i in u:
    fr=i.split('/')[-1]
    r=requests.get(i, stream=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-134-11b167660ce4> in <module>
#       2 for i in u:
#       3     fr=i.split('/')[-1]
# ----> 4     r=requests.get(i, stream=True)
#
# NameError: name 'requests' is not defined

# %%
import os
from GoogleImageScraper import GoogleImageScraper
from patch import webdriver_executable
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-14f284d9b137> in <module>
#       1 import os
# ----> 2 from GoogleImageScraper import GoogleImageScraper
#       3 from patch import webdriver_executable
#
# ModuleNotFoundError: No module named 'GoogleImageScraper'

# %%
webdriver_path = os.path.normpath(os.path.join(os.getcwd(), 'webdriver', webdriver_executable()))
image_path = os.path.normpath(os.path.join(os.getcwd(), 'photos'))
#add new search key into array [‘fruits’, ‘cars’, ‘Machine Learning’, ‘Guitar’, ‘Cakes’]
search_keys= ["fruits", "cars","Machine Learning", "Guitar", "Cakes"]
number_of_images = 10
headless = False
#min_resolution = (width,height)
min_resolution=(0,0)
#max_resolution = (width,height)
max_resolution=(1920,1080)
for search_key in search_keys:
    image_scraper = GoogleImageScraper(webdriver_path,image_path,search_key,number_of_images,headless,min_resolution,max_resolution)
    image_urls = image_scraper.find_image_urls()
    image_scraper.save_images(image_urls)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b9b509fbd06e> in <module>
# ----> 1 webdriver_path = os.path.normpath(os.path.join(os.getcwd(), 'webdriver', webdriver_executable()))
#       2 image_path = os.path.normpath(os.path.join(os.getcwd(), 'photos'))
#       3 #add new search key into array [‘fruits’, ‘cars’, ‘Machine Learning’, ‘Guitar’, ‘Cakes’]
#       4 search_keys= ["fruits", "cars","Machine Learning", "Guitar", "Cakes"]
#       5 number_of_images = 10
#
# NameError: name 'webdriver_executable' is not defined

# %% [markdown]
# # 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https://www.flipkart.com/'
driver.get(url)
sleep(2)

# %%
# Searching for the place to give the product name
search_job=driver.find_elements(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')

# %%
# Entering the product in searching tab
search_job[0].send_keys('Oneplus Nord')

# %%
# Pressing Enter for searching
from selenium.webdriver.common.keys import Keys
search_job[0].send_keys(Keys.ENTER)
sleep(2)

# %%
n=driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')

# %%
r=driver.find_elements(By.XPATH,'//div[@class="_30jeq3 _1_WHN1"]')

# %%
d=driver.find_elements(By.XPATH,'//div[@class="fMghEO"]')

# %%
nam=[]
col=[]
ram=[]
rat=[]
dis=[]
cam=[]
bat=[]
for i in range(0,24):
    nam.append(n[i].text.split('(')[0])
    col.append(n[i].text.split('(')[1].split()[0:-2])
    ram.append(n[i].text.split('(')[1].split()[-2:-1])
    rat.append(r[i].text)
    dis.append(d[i].text.split('\n')[1].split()[0])
    cam.append(d[i].text.split('\n')[2].split()[0])
    bat.append(d[i].text.split('\n')[3].split()[0])

# %%
f=pd.DataFrame(list(zip(nam,col,ram,rat,dis,cam,bat)),
               columns =['Name', 'Company','Ram','Cost','Display','Camera','Battery'])

# %%
f
# Out:
#                           Name           Company    RAM     COST DISPLAY  \
# 0   OnePlus Nord CE 2 Lite 5G     [Black, Dusk,]  [128]  ₹19,878   16.74
# 1   OnePlus Nord CE 2 Lite 5G      [Blue, Tide,]  [128]  ₹19,890   16.74
# 2   OnePlus Nord CE 2 Lite 5G      [Blue, Tide,]  [128]  ₹21,999   16.74
# 3          OnePlus Nord 2T 5G    [Gray, Shadow,]  [128]  ₹28,990   17.02
# 4          OnePlus Nord 2T 5G    [Gray, Shadow,]  [256]  ₹33,999   17.02
# 5        OnePlus Nord CE 2 5G    [Gray, Mirror,]  [128]  ₹24,999   16.33
# 6           OnePlus Nord 2 5G      [Blue, Haze,]  [128]  ₹29,125   16.33
# 7           OnePlus Nord 2 5G    [Gray, Sierra,]  [128]  ₹29,990   16.33
# 8                OnePlus Nord      [Gray, Onyx,]  [256]  ₹29,999   16.36
# 9                OnePlus Nord      [Gray, Onyx,]   [64]  ₹24,999   16.36
# 10               OnePlus Nord    [Blue, Marble,]  [256]  ₹29,999   16.36
# 11               OnePlus Nord      [Gray, Onyx,]  [128]  ₹27,999   16.36
# ...

# %%
f.to_csv(r'C:\OnePlus Nord.csv',index= False)

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https://www.flipkart.com/'
driver.get(url)
sleep(2)

# %%
# Searching for the place to give the product name
search_job=driver.find_elements(By.XPATH,'/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')

# %%
# Entering the product in searching tab
search_job[0].send_keys('pixel 4A')

# %%
# Pressing Enter for searching
from selenium.webdriver.common.keys import Keys
search_job[0].send_keys(Keys.ENTER)
sleep(2)

# %%
n=driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')

# %%
r=driver.find_elements(By.XPATH,'//div[@class="_30jeq3 _1_WHN1"]')

# %%
d=driver.find_elements(By.XPATH,'//div[@class="fMghEO"]')

# %%
nam=[]
col=[]
ram=[]
rat=[]
dis=[]
cam=[]
bat=[]
for i in range(0,24):
    nam.append(n[i].text.split('(')[0])
    col.append(n[i].text.split('(')[1].split()[0:-2])
    ram.append(n[i].text.split('(')[1].split()[-2:-1])
    rat.append(r[i].text)
    dis.append(d[i].text.split('\n')[1].split()[0])
    cam.append(d[i].text.split('\n')[2].split()[0])
    bat.append(d[i].text.split('\n')[3].split()[0])

# %%
f=pd.DataFrame(list(zip(nam,col,ram,rat,dis,cam,bat)),
               columns =['Name', 'Colour','Ram','Cost','Display','Camera','Battery'])

# %%
f
# Out:
#                     Name                Colour    Ram     Cost Display  \
# 0       Google Pixel 4a         [Just, Black,]  [128]  ₹31,999   14.76
# 1   REDMI 10 PRIME 2022      [Phantom, Black,]   [64]  ₹11,347   16.51
# 2           vivo T1 44W           [Ice, Dawn,]  [128]  ₹14,499   16.36
# 3           vivo T1 44W         [Starry, Sky,]  [128]  ₹14,499   16.36
# 4           vivo T1 44W    [Midnight, Galaxy,]  [128]  ₹14,499   16.36
# 5           vivo T1 44W    [Midnight, Galaxy,]  [128]  ₹15,999   16.36
# 6           vivo T1 44W         [Starry, Sky,]  [128]  ₹15,999   16.36
# 7       Infinix Smart 6   [Light, Sea, Green,]   [64]   ₹7,199   16.76
# 8       Infinix Smart 6    [Heart, Of, Ocean,]   [64]   ₹7,199   16.76
# 9       Infinix Smart 6      [Starry, Purple,]   [64]   ₹7,199   16.76
# 10            REDMI 10A           [Sea, Blue,]   [64]   ₹9,145   16.59
# 11       Redmi 9A Sport       [Carbon, Black,]   [32]   ₹6,823   16.59
# ...

# %%
f.to_csv(r'C:\pixel 4A.csv',index= False)

# %% [markdown]
# # 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
import time

# %%
# Connecting to the webpage
url= 'https://www.google.com/maps/@13.1369289,77.5963159,15z'
driver.get(url)
time.sleep(2)

# %%
search_job=driver.find_elements(By.XPATH,'/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/form/div[2]/div[3]/div/input[1]')

# %%
# Entering the city name required for search
product=input(str('Enter the product name you wish to search for: '))
# Out:
# Enter the product name you wish to search for: Bangalore

# %%
# Entering the product in searching tab
search_job[0].send_keys(product)

# %%
# Clicking the search button
search=driver.find_elements(By.XPATH,'/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/div[1]/button')

# %%
search[0].click()

# %%
c=driver.find_elements(By.XPATH,'/html/body/div[3]/div[9]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[4]/div[3]/button/span')
c[0].click()

# %%
g=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[1]/ul/li[1]')

# %%
g[0].text
# Out:
# '13.00738, 77.58900'

# %% [markdown]
# # 6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in.

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')
import time

# %%
# Connecting to the webpage
url= 'https://trak.in/india-startup-funding-investment-2015/'
driver.get(url)
time.sleep(2)

# %%
e=driver.find_elements(By.XPATH,'/html/body/div[1]/main/div/div/div/div[2]/div[1]/div/div/div/div[1]/div/div[5]/div[1]/label/select')
e[0].click()

# %%
a=driver.find_elements(By.XPATH,'//body//div[3]/div[2]/table/tbody/tr/td')

# %%
a[27].text
# Out:
# '4'

# %% [markdown]
# # April

# %%
s=[]
d=[]
sn=[]
it=[]
sv=[]
c=[]
r=[]
ity=[]
am=[]
for i in range (0,5):
    s.append(a[i*9].text)
    d.append(a[((i*9)+1)].text)
    sn.append(a[((i*9)+2)].text)
    it.append(a[((i*9)+3)].text)
    sv.append(a[((i*9)+4)].text)
    c.append(a[((i*9)+5)].text)
    r.append(a[((i*9)+6)].text)
    ity.append(a[((i*9)+7)].text)
    am.append(a[((i*9)+8)].text)

# %%
import pandas as pd
zi= pd.DataFrame(list(zip(s,d,sn,it,sv,c,r,ity,am)),columns =['Sl.no','Date','Startup name','Industry','Sub-vertical','City','Investor name','Investor type','Amount'])

# %%
zi
# Out:
#   Sl.no        Date Startup name              Industry  \
# 0     1  01/04/2021       BYJU’S              Edu-tech
# 1     2  05/04/2021       Meesho            E-commerce
# 2     3  14/04/2021       Swiggy  Online Food Delivery
# 3     4  07/04/2021        Groww               FinTech
# 4     5  14/04/2021      Beldara            E-commerce
#
#                 Sub-vertical       City  \
# 0            Online tutoring  Bengaluru
# 1  Online reselling platform  Bengaluru
# 2       Online Food Delivery  Bengaluru
# 3        Investment platform  Bengaluru
# 4     Global B2B marketplace     Mumbai
#
#                                        Investor name Investor type  \
# 0                                    Innoven Capital      Series F
# 1                             SoftBank Vision Fund 2      Series E
# 2  Amansa Holdings, Carmignac, Falcon Edge Capita...      Series J
# 3         MC Global Edtech, B Capital, Baron, others      Series D
# ...

# %% [markdown]
# # March

# %%
s=[]
d=[]
sn=[]
it=[]
sv=[]
c=[]
r=[]
ity=[]
am=[]
for i in range (5,12):
    s.append(a[i*9].text)
    d.append(a[((i*9)+1)].text)
    sn.append(a[((i*9)+2)].text)
    it.append(a[((i*9)+3)].text)
    sv.append(a[((i*9)+4)].text)
    c.append(a[((i*9)+5)].text)
    r.append(a[((i*9)+6)].text)
    ity.append(a[((i*9)+7)].text)
    am.append(a[((i*9)+8)].text)

# %%
import pandas as pd
zi3= pd.DataFrame(list(zip(s,d,sn,it,sv,c,r,ity,am)),columns =['Sl.no','Date','Startup name','Industry','Sub-vertical','City','Investor name','Investor type','Amount'])

# %%
zi3
# Out:
#   Sl.no        Date Startup name    Industry  \
# 0     1  04/03/2021    DealShare  E-commerce
# 1     2  31/03/2021     Uniphore  Technology
# 2     3  30/03/2021        Dunzo  E-commerce
# 3     4  30/03/2021       BYJU’S    Edu-tech
# 4     5  23/03/2021  SkilloVilla    Edu-tech
# 5     6  25/03/2021     CityMall  E-commerce
# 6     7  26/03/2021        DotPe     FinTech
#
#                                         Sub-vertical               City  \
# 0                           Online shopping platform  Jaipur, Rajasthan
# 1            Conversational Service Automation (CSA)          Palo Alto
# 2                           Hyper-local delivery app          Bengaluru
# 3                                    Online tutoring          Bengaluru
# 4                Career and job-oriented upskilling.          Bengaluru
# 5       Social ecommerce and online grocery platform            Gurgaon
# 6  Commerce and payments platform to offline ente...            Gurgaon
#
# ...

# %% [markdown]
# # feburary

# %%
s=[]
d=[]
sn=[]
it=[]
sv=[]
c=[]
r=[]
ity=[]
am=[]
for i in range (12,21):
    s.append(a[i*9].text)
    d.append(a[((i*9)+1)].text)
    sn.append(a[((i*9)+2)].text)
    it.append(a[((i*9)+3)].text)
    sv.append(a[((i*9)+4)].text)
    c.append(a[((i*9)+5)].text)
    r.append(a[((i*9)+6)].text)
    ity.append(a[((i*9)+7)].text)
    am.append(a[((i*9)+8)].text)

# %%
import pandas as pd
zi2= pd.DataFrame(list(zip(s,d,sn,it,sv,c,r,ity,am)),columns =['Sl.no','Date','Startup name','Industry','Sub-vertical','City','Investor name','Investor type','Amount'])

# %%
zi2
# Out:
#   Sl.no        Date Startup name     Industry                   Sub-vertical  \
# 0     1  11/02/2021     Doubtnut     Edu Tech            E-Learning Platform
# 1     2  22/02/2021       Zomato  Hospitality  Online Food Delivery Platform
# 2     3  19/02/2021    Fingerlix  Hospitality  Semi-cooked food delivery app
# 3     4  17/02/2021        Zolve      FinTech         Global Neobank Venture
# 4     5  15/02/2021    KreditBee      Finance       Digital lending platform
# 5     6  12/02/2021    Pepperfry   E-commerce    Multi-brand furniture brand
# 6     7  12/02/2021      Grofers   E-Commerce             Online supermarket
# 7     8  09/02/2021      Nothing   Technology    Consumer Technology Venture
# 8     9  09/02/2021  SplashLearn       EdTech  Game-based learning programme
#
#         City                                      Investor name  \
# 0    Gurgaon  SIG Global, Sequoia Capital, WaterBridge Ventu...
# 1    Gurgaon                                 Tiger Global, Kora
# ...

# %% [markdown]
# # January

# %%
s=[]
d=[]
sn=[]
it=[]
sv=[]
c=[]
r=[]
ity=[]
am=[]
for i in range (21,29):
    s.append(a[i*9].text)
    d.append(a[((i*9)+1)].text)
    sn.append(a[((i*9)+2)].text)
    it.append(a[((i*9)+3)].text)
    sv.append(a[((i*9)+4)].text)
    c.append(a[((i*9)+5)].text)
    r.append(a[((i*9)+6)].text)
    ity.append(a[((i*9)+7)].text)
    am.append(a[((i*9)+8)].text)

# %%
import pandas as pd
zi1= pd.DataFrame(list(zip(s,d,sn,it,sv,c,r,ity,am)),columns =['Sl.no','Date','Startup name','Industry','Sub-vertical','City','Investor name','Investor type','Amount'])

# %%
zi1
# Out:
#   Sl.no        Date            Startup name                Industry  \
# 0     1  15/01/2021         Digit Insurance      Financial Services
# 1     2  28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 2     3  19/01/2021                  DeHaat        AgriTech Startup
# 3     4  19/01/2021               Darwinbox                    SaaS
# 4     5  18/01/2021                   mfine     Health Tech Startup
# 5     6  18/01/2021                   Udayy                  EdTech
# 6     7  11/01/2021           True Elements            Food Startup
# 7     8  13/01/2021                   Saveo          B2B E-commerce
#
#                                         Sub-vertical       City  \
# 0                                 Insurance Services  Bengaluru
# 1      Shave care, beard care, and skincare products  New Delhi
# 2  online marketplace for farm products and services      Patna
# 3                                            HR Tech     Mumbai
# ...

# %%
q=pd.concat([zi1,zi2,zi3,zi],ignore_index= True)

# %%
q
# Out:
#    Sl.no        Date            Startup name                Industry  \
# 0      1  15/01/2021         Digit Insurance      Financial Services
# 1      2  28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 2      3  19/01/2021                  DeHaat        AgriTech Startup
# 3      4  19/01/2021               Darwinbox                    SaaS
# 4      5  18/01/2021                   mfine     Health Tech Startup
# 5      6  18/01/2021                   Udayy                  EdTech
# 6      7  11/01/2021           True Elements            Food Startup
# 7      8  13/01/2021                   Saveo          B2B E-commerce
# 8      1  11/02/2021                Doubtnut                Edu Tech
# 9      2  22/02/2021                  Zomato             Hospitality
# 10     3  19/02/2021               Fingerlix             Hospitality
# 11     4  17/02/2021                   Zolve                 FinTech
# 12     5  15/02/2021               KreditBee                 Finance
# ...

# %% [markdown]
# # 7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')
import time

# %%
# Connecting to the webpage
url= 'https://www.digit.in/'
driver.get(url)
time.sleep(2)

# %%
a=driver.find_elements(By.XPATH,'/html/body/div[1]/div/div[3]/div[2]/a/img')

# %%
a[0].click()

# %%
search_job=driver.find_elements(By.XPATH,'/html/body/div[2]/div[2]/div/div/input')

# %%
# Entering the product in searching tab
search_job[0].send_keys('best gaming laptops')

# %%
# Pressing Enter for searching
from selenium.webdriver.common.keys import Keys
search_job[0].send_keys(Keys.ENTER)

# %%
t=[]
for i in range (0,10):
    d=driver.find_elements(By.XPATH,'//div[@class="searchProduct-desc"]')
    t.append(d[i].text)
for a in range (0,499):
    nex=driver.find_elements(By.XPATH,'/html/body/div[6]/div[2]/div[2]/div[13]/nav/ul/li[a]/a')
    nex[0].click()
    for o in range (0,10):
        d=driver.find_elements(By.XPATH,'//div[@class="searchProduct-desc"]')
        t.append(d[o].text)

# %%
# All the names of the gaming laptop
t
# Out:
# ['Asus G750JX-CV069P',
#  'Lenovo G50-30',
#  'HP Envy 15-k006tx',
#  'HP Envy dv6-7206tx notebook',
#  'Dell 15 (2021) i5-10200H',
#  'Sony PlayStation Vita',
#  'Dell Vostro 15 3500',
#  "ASUS G53J - A 3D gamer's delight but we want more",
#  'Lenovo IdeaPad Y570',
#  'ASUS ROG Flow x13',
#  'HP Pavilion g6 - Multimedia and gaming on a budget',
#  'ASUS ROG Cetra',
#  'London 2012: Official Mobile Game (Android and iOS)',
#  'ASUS Zephyrus G15 Ryzen 9 5900HS (2021)',
#  'Acer Aspire E15 E5-573G',
#  'HP Envy 4-1002TX',
#  'Best high-end gaming laptops on Amazon India',
#  'Digit Zero1 Awards 2019: Best Performing Gaming Laptops',
#  'Best AMD Ryzen powered laptops for AAA gaming',
#  'Best gaming laptops with good sound on Amazon India',
#  'Samsung Series 9 (NP-900X3C)',
#  'Asus GTX980 Matrix Platinum',
#  'Cooler Master Storm Devastator',
#  'Asus TUF Gaming FX505',
#  'Dell Alienware (17-inch)',
#  'MSI GE60 2PE',
#  'Best gaming laptops under Rs 60,000',
# ...

# %% [markdown]
# # 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')
import time

# %%
# Connecting to the webpage
url= 'https://www.forbes.com/real-time-billionaires/#60ccecfe3d78'
driver.get(url)
time.sleep(2)

# %% [raw]
# For extracting the features from the table of forbes

# %%
ra=driver.find_elements(By.XPATH,"//table[@class='ng-scope ng-table'][1]/tbody/tr/td[2]")

# %%
na=driver.find_elements(By.TAG_NAME,'h3')

# %%
r=[]
for rc in ra:
    r.append(rc.text)

# %%
n=[]
for i in range(0,len(na)):
    n.append(na[i].text)

# %%
net=driver.find_elements(By.XPATH,"//table[@class='ng-scope ng-table'][1]/tbody/tr/td[4]")

# %%
nw=[]
for n in net:
    nw.append(n.text)

# %%
age=driver.find_elements(By.XPATH,"//table[@class='ng-scope ng-table'][1]/tbody/tr/td[6]")

# %%
a=[]
for ag in age:
    a.append(ag.text)

# %%
sour=driver.find_elements(By.XPATH,"//table[@class='ng-scope ng-table'][1]/tbody/tr/td[7]")

# %%
s=[]
for so in sour:
    s.append(so.text)

# %%
cou=driver.find_elements(By.XPATH,"//table[@class='ng-scope ng-table'][1]/tbody/tr/td[8]")

# %%
c=[]
for co in cou:
    c.append(co.text)

# %%
p= pd.DataFrame(list(zip(r,n,nw,a,s,c)),
               columns =['Rank', 'Name','Net Worth','Age','Source','Country'])

# %%
# Dataset after extraction
p
# Out:
#     Rank                      Name Net Worth Age                       Source  \
# 0      1                 Elon Musk  $271.2 B  51                Tesla, SpaceX
# 1      2  Bernard Arnault & family  $165.9 B  73                         LVMH
# 2      3                Jeff Bezos  $160.6 B  58                       Amazon
# 3      4     Gautam Adani & family  $120.8 B  60  infrastructure, commodities
# 4      5                Bill Gates  $109.7 B  66                    Microsoft
# ..   ...                       ...       ...  ..                          ...
# 170  171               Dang Yanbao   $10.9 B  49                         coal
# 171  172           Philip Anschutz   $10.8 B  82                  investments
# 172  173                 Carl Cook   $10.8 B  59              medical devices
# 173  174         Sarath Ratanavadi   $10.8 B  57                       energy
# 174  175           Harry Triguboff   $10.7 B  89                  real estate
#
#            Country
# ...

# %% [markdown]
# # 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https://www.youtube.com/watch?v=uNi3aYr1VaQ'
driver.get(url)

# %%
# Clicking on comments
po=driver.find_elements(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[2]/ytd-watch-metadata/div/div[3]/div[2]/ytd-comments-entry-point-header-renderer/div[1]/div[1]')
time.sleep(2)

# %%
po[0].click()

# %%
a=driver.find_elements(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[2]/div[1]/ytd-engagement-panel-section-list-renderer[3]/div[2]/ytd-section-list-renderer/div[2]/ytd-comments/ytd-item-section-renderer/div[3]/ytd-comment-thread-renderer[453]/ytd-comment-renderer/div[3]/div[2]/div[1]/div[2]/h3/a/span')
driver.execute_script("arguments[0].scrollIntoVeiw();",a)

# %%
na=driver.find_elements(By.XPATH,"//span [@class=' style-scope ytd-comment-renderer']")
co=driver.find_elements(By.XPATH,"//div/yt-formatted-string[@id='content-text']")
ti=driver.find_elements(By.XPATH,"//div[3]/div[2]/div[1]/div[2]/yt-formatted-string/a")

# %%
n=[]
c=[]
t=[]
for i in range (0,500):
    n.append(na[i].text)
    c.append(co[i].text)
    t.append(ti[i].text)

# %%
p= pd.DataFrame(list(zip(n,c,t)),
               columns =['Name', 'Comment','Time'])

# %%
p[0:458]
# Out:
#                     Name                                            Comment  \
# 0            YuvaTronics  Palki is eye opener in many aspects. She alway...
# 1          Angelo Forido  I became aware of this situation years ago so ...
# 2        maanya upadhyay  Storytelling is an art , Palki is the artist. ...
# 3             Anil Kumar  Truly appreciated the class of Palki's journal...
# 4     Dances with Fishes  I agree 100%. I stopped donating to the “Big F...
# ..                   ...                                                ...
# 453          AJay Sharma  Main 1 Rupeeya bhejta hun aur public ko 15 Pai...
# 454        Kunal Agarwal  This is the reason i never donate to any organ...
# 455           jane andre  the aid should be in kind  worldwidr because d...
# 456       Dietmar Selzer                         Yes it is all a big Scam !
# 457  Dnyaneshwar Bhutnar
#
#                Time
# 0      16 hours ago
# 1      17 hours ago
# 2      16 hours ago
# 3      16 hours ago
# ...

# %% [markdown]
# # 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https://www.hostelworld.com/'
driver.get(url)

# %%
# Searching for the place to give the product name
search_job=driver.find_elements(By.XPATH,'/html/body/div[3]/div/div/div[1]/div[1]/div/div/div[4]/div/div[2]/div/div[1]/div/div/div/input')

# %%
# Entering the product in searching tab
search_job[0].send_keys('London')

# %%
cli=driver.find_elements(By.XPATH,'/html/body/div[3]/div/div/div[1]/div[1]/div/div/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]/div')
time.sleep(2)

# %%
cli[0].click()

# %%
q=driver.find_elements(By.XPATH,'/html/body/div[3]/div/div/div[1]/div[1]/div/div/div[4]/div/div[2]/div/div[2]/div[1]/span[2]')
time.sleep(2)

# %%
q[0].click()

# %%
w=driver.find_elements(By.XPATH,'/html/body/div[3]/div/div/div[1]/div[1]/div/div/div[4]/div/div[2]/div/div[2]/div[2]/div/div[14]/div')
time.sleep(2)

# %%
w[0].click()

# %%
#setting arrival date
u=driver.find_elements(By.XPATH,'/html/body/div[3]/div/div/div[1]/div[1]/div/div/div[4]/div/div[2]/div/div[3]/div[1]/span[2]')
time.sleep(2)

# %%
u[0].click()
time.sleep(2)

# %%
#setting departure date
m=driver.find_elements(By.XPATH,'/html/body/div[3]/div/div/div[1]/div[1]/div/div/div[4]/div/div[2]/div/div[3]/div[2]/div/div[35]/div')
time.sleep(2)

# %%
m[0].click()
time.sleep(2)

# %%
# Clicking on the lets go option
lg=driver.find_elements(By.XPATH,'/html/body/div[3]/div/div/div[1]/div[1]/div/div/div[4]/div/div[2]/div/div[5]/button')
time.sleep(2)

# %%
lg[0].click()
time.sleep(2)

# %%
name=driver.find_elements(By.XPATH,"//h2[@class='title title-6']")
d=driver.find_elements(By.XPATH,"//span[@class='description']")
r=driver.find_elements(By.XPATH,"//div[@class='bottom-rating']")
tr=driver.find_elements(By.XPATH,"//div[@class='reviews']")
v=driver.find_elements(By.XPATH,"//div[@class='keyword']")
p=driver.find_elements(By.XPATH,"//div[@class='price title-5']"and"//div[@class='price-col']")

# %%
hn=[]
dis=[]
rat=[]
tore=[]
for i in range (0,30):
    hn.append(name[i].text)
    dis.append(d[i].text.split()[2])
    rat.append(r[i].text.split('\n')[0])
    tore.append(tr[i].text.split()[0])

# %%
wr=[]
for i in range (2, 32):
    wr.append(v[i].text)

# %%
len(wr)
# Out:
# 30

# %%
pri=[]
do=[]
for i in range (0,60):
    if (i%2==0):
        pri.append(p[i].text)
    else:
        do.append(p[i].text)

# %%
p[8].text
# Out:
# 'No Privates Available'

# %%
pd=[]
url=driver.find_elements(By.XPATH,"//h2/a[@href]")
for i in url:
    pd.append(i.get_attribute('href'))

# %%
len(pd)
# Out:
# 30

# %%
p=[]
for i in pd:
    driver.get(i)
    time.sleep(5)
    try:
        d=driver.find_elements(By.XPATH,"//div[@class='content collapse-content']")
        p.append(d[0].text)
    except:
        p.append(Nan)

# %%
len(p)
# Out:
# 30

# %%
p
# Out:
# ["Whether you're a backpacker, flash-packer or a budget traveller, Palmers Lodge has everything you need for one of the most unique experiences in London! Combining the grand charm of our historic building constucted in 1882, our friendly team and accessible location, Palmers Lodge has it all. \n\nSwiss Cottage boasts not only a fantastic London city location and building but our services are unbeatable! We have a 24 hour reception so you can be assured we are always there when you need us, you can meet other like-minded travellers downstairs at Swiss Bar - taking advantage of our selections of drinks and snacks.\n\nAn added bonus is that beds are pre-made and come with linen all for free, so the late arriving lodger can jump straight into bed, or the bar! We also offer free Wi-Fi throughout the hostel so you can stay in touch with the rest of the world and explore what's on in London! \n\nIt is easy to forget when you stay at Swiss Cottage that there is a vibrant city just outside w
# ...

# %%
import pandas as pd
zi= pd.DataFrame(list(zip(hn,dis,rat,tore,wr,pri,do,p)),columns =['Hostel Name','Distance from city','Rating','Total Rating','Word of rating','Private room','Doom','Description'])

# %%
zi
# Out:
#                                 Hostel Name Distance from city     Rating  \
# 0             Palmers Lodge - Swiss Cottage              6.5km        8.8
# 1                             Selina Camden              5.5km        8.5
# 2                          Generator London                3km        7.7
# 3         Safestay London Elephant & Castle              1.7km        7.0
# 4                   Smart Camden Inn Hostel              4.4km        8.4
# 5                        No.8 Seven Sisters                9km        6.2
# 6   Safestay London Kensington Holland Park              5.9km        6.5
# 7                   Queen Elizabeth Chelsea              5.7km        6.8
# 8                          NX London Hostel              6.1km        7.3
# 9                    London Waterloo Hostel              0.7km        6.3
# 10           PubLove @ The Crown, Battersea              4.7km        6.5
# 11                  Saint James Backpackers              5.5km        6.6
# ...
