# %% [markdown]
# # 1.Scrape the details of most viewed videos on YouTube from Wikipedia.Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
# Importing librabries
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)

# %%
# Getting to the webpage
x=driver.find_elements(By.XPATH,'/html/body/div[3]/div[3]/div[5]/div[1]/div[2]/ul/li[1]/a/span[2]')

# %%
x[0].click()

# %%
r=driver.find_elements(By.XPATH,'//body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td')

# %%
# Scapping the information in the list
ra=[]
n=[]
a=[]
u=[]
v=[]
for i in range(0,29):
    ra.append(r[(i*6)].text)
    n.append(r[((i*6)+1)].text)
    a.append(r[((i*6)+2)].text)
    u.append(r[((i*6)+3)].text)
    v.append(r[((i*6)+4)].text)

# %%
# Buliding Dataset using scrapped information
p= pd.DataFrame(list(zip(ra,n,a,u,v)),
               columns =['Rank', 'Name','Artist','Veiws(Billions) ','Upload Date'])

# %%
p
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.                                "Uptown Funk"[22]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9   10.   "Masha and the Bear – Recipe for Disaster"[24]
# 10  11.                              "Gangnam Style"[25]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# ...

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https://www.bcci.tv/.'
driver.get(url)
time.sleep(2)

# %%
# Getting to the webpage
s=driver.find_elements(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')

# %%
s[0].click()
time.sleep(2)

# %%
# Scapping the information in the list
mt=[]
Da=[]
ti=[]
c=[]
ser=[]
pa=[]
y=driver.find_elements(By.XPATH,'//span[@class="ng-binding"]')
t=driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]')
d=driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]')
s=driver.find_elements(By.XPATH,'//span[@class="ng-binding ng-scope"]')
se=driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]')
p=driver.find_elements(By.XPATH,'//div[@class="fix-place ng-binding ng-scope"]')
for i in range(0,5):
    mt.append(y[i].text)
    Da.append(t[i].text)
    ti.append(d[i].text)
    c.append(s[i].text)
    ser.append(se[i].text)
    pa.append(p[i].text.split()[-1])

# %%
# Buliding Dataset using scrapped information
p= pd.DataFrame(list(zip(mt,Da,ti,c,ser,pa)),
               columns =['Match Title', 'Date','Time','Club','Series Name','Place'])

# %%
p
# Out:
#                                  Match Title         Date          Time  \
# 0    COMMONWEALTH GAMES WOMEN'S CRICKET 2022   3 AUG 2022  10:30 PM IST
# 1  INDIA TOUR OF WEST INDIES T20 SERIES 2022   6 AUG 2022   8:00 PM IST
# 2  INDIA TOUR OF WEST INDIES T20 SERIES 2022   7 AUG 2022   8:00 PM IST
# 3     INDIA TOUR OF ZIMBABWE ODI SERIES 2022  18 AUG 2022  12:45 PM IST
# 4     INDIA TOUR OF ZIMBABWE ODI SERIES 2022  20 AUG 2022  12:45 PM IST
#
#                                                 Club Series Name       Place
# 0                                         Edgbaston,   3rd T20 -  Birmingham
# 1  Central Broward Regional Park Stadium Turf Gro...  4th T20I -     Florida
# 2  Central Broward Regional Park Stadium Turf Gro...  5th T20I -     Florida
# 3                                Harare Sports Club,   1st ODI -      Harare
# 4                                Harare Sports Club,   2nd ODI -      Harare

# %% [markdown]
# # 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https://www.guru99.com/'
driver.get(url)
time.sleep(2)

# %%
# Getting to the webpage
f=driver.find_elements(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input')

# %%
f[0].send_keys('selenium exception')

# %%
q=driver.find_elements(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button')

# %%
q[0].click()

# %%
# Scapping the information in the list
n=[]
d=[]
u=driver.find_elements(By.XPATH,'//div [@class="gsc-expansionArea"]')
for i in range (0,9):
    n.append(t[i*3])
    d.append(t[(i*3)+2])

# %%
t=u[0].text.split('\n')

# %%
d
# Out:
# ['23-Jul-2022 ... Common Exceptions in Selenium Web driver ; NoSuchWindowException, This Exception occurs if the window target to be switch does not exist.',
#  '16-Jul-2022 ... Once we set the time, the web driver will wait for the element for that time before throwing an exception. Selenium Web Driver has borrowed ...',
#  '25-Jun-2022 ... Need to adjust our script in such a way that it will take care of SSL Exception/error by itself through Selenium Web driver. You Might Like: How ...',
#  '09-Jul-2022 ... In Java, exceptions are mainly used for indicating different types of error conditions. In this tutorial, you will learn-. What is Exception?',
#  '25-Jun-2022 ... iFrame in Selenium Webdriver is a web page or an inline frame which is embedded in ... Selenium Exception Handling (Common Exceptions List) ...',
#  '18-Jun-2022 ... While Testing exception, you need to ensure that exception class you are providing in that optional parameter of @test annotation is the same.',
# ...

# %%
# Buliding Dataset using scrapped information
p= pd.DataFrame(list(zip(n,d)),
               columns =['Name', 'Discription'])

# %%
p
# Out:
#                                                 Name  \
# 0  Selenium Exception Handling (Common Exceptions...
# 1  Implicit, Explicit and Fluent Wait in Selenium...
# 2  How to Handle SSL Certificate in Selenium WebD...
# 3      Try Catch in Java: Exception Handling Example
# 4  How to Handle iFrames in Selenium Webdriver: s...
# 5     JUnit Expected Exception Test: @Test(expected)
# 6  Download Geckodriver: How to Install Using Fir...
# 7       How to Create User Defined Exception in Java
# 8  Python Exception Handling: try, catch, finally...
#
#                                          Discription
# 0  23-Jul-2022 ... Common Exceptions in Selenium ...
# 1  16-Jul-2022 ... Once we set the time, the web ...
# 2  25-Jun-2022 ... Need to adjust our script in s...
# 3  09-Jul-2022 ... In Java, exceptions are mainly...
# 4  25-Jun-2022 ... iFrame in Selenium Webdriver i...
# 5  18-Jun-2022 ... While Testing exception, you n...
# 6  18-Jun-2022 ... Before Selenium 3, Mozilla Fir...
# ...

# %% [markdown]
# # 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)
# D) GSDP(17-18)
# E) Share(2017)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'http://statisticstimes.com/ '
driver.get(url)
time.sleep(2)

# %%
n=driver.find_elements(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button')

# %%
n[0].click()

# %%
# Getting to the webpage
p=driver.find_elements(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')

# %%
p[0].click()

# %%
k=driver.find_elements(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')

# %%
k[0].click()

# %%
# Scapping the information in the list
r=[]
sta=[]
g2=[]
m=driver.find_elements(By.XPATH,'//td [@class="data1"]')
n=driver.find_elements(By.XPATH,'//td [@class="name"]')
g20=driver.find_elements(By.XPATH,'//td [@class="data sorting_1"]')
for i in range(0,33):
    r.append(m[i].text)
    sta.append(n[i].text)
    g2.append(g20[i].text)

# %%
g1=[]
s=[]
f=[]
g19=driver.find_elements(By.XPATH,'//td [@class="data"]')
for i in range (0,33):
    g1.append(g19[i*5].text)
    s.append(g19[(i*5)+1].text)
    f.append(g19[(i*5)+4].text)

# %%
# Buliding Dataset using scrapped information
p= pd.DataFrame(list(zip(r,sta,g1,g2,s,f)),
               columns =['Rank', 'State', 'GSDP(18-19)', 'GSDP(19-20)','Share(18-19)','GDP($ billion)'])

# %%
p
# Out:
#    Rank                      State GSDP(18-19) GSDP(19-20) Share(18-19)  \
# 0     1                Maharashtra           -   2,632,792       13.94%
# 1     2                 Tamil Nadu   1,845,853   1,630,208        8.63%
# 2     3              Uttar Pradesh   1,687,818   1,584,764        8.39%
# 3     4                    Gujarat           -   1,502,899        7.96%
# 4     5                  Karnataka   1,631,977   1,493,127        7.91%
# 5     6                West Bengal   1,253,832   1,089,898        5.77%
# 6     7                  Rajasthan   1,020,989     942,586        4.99%
# 7     8             Andhra Pradesh     972,782     862,957        4.57%
# 8     9                  Telangana     969,604     861,031        4.56%
# 9    10             Madhya Pradesh     906,672     809,592        4.29%
# 10   11                     Kerala           -     781,653        4.14%
# 11   12                      Delhi     856,112     774,870        4.10%
# ...

# %% [markdown]
# # Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https://github.com/ '
driver.get(url)
time.sleep(2)

# %%
# Getting to the webpage
s=driver.find_elements(By.XPATH,'/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary')
s[0].click()

# %%
q=driver.find_elements(By.XPATH,'/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a')
q[0].click()

# %%
# Scapping the information in the list
ti=[]
t=driver.find_elements(By.XPATH,'//h1[@class="h3 lh-condensed"]')
for i in range(0,25):
    ti.append(t[i].text)

# %%
de=[]
d=driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in range(0,23):
     de.append(d[i].text)

# %%
la=[]
l=driver.find_elements(By.XPATH,'//span[@class="d-inline-block ml-0 mr-3"]')
for i in range(0,20):
     la.append(l[i].text)

# %%
s=[]
co=[]
c=driver.find_elements(By.XPATH,'//a[@class="Link--muted d-inline-block mr-3"]')
for i in range(0,25):
    s.append(c[((i*2)+1)].text)
    co.append(c[(i*2)].text)

# %%
de.insert(0,'Nan')

# %%
de.insert(14,'Nan')

# %%
la.insert(6,'Nan')

# %%
la.insert(10,'Nan')

# %%
la.insert(12,'Nan')

# %%
la.insert(19,'Nan')

# %%
la.insert(24,'Nan')

# %%
# Buliding Dataset using scrapped information
p= pd.DataFrame(list(zip(ti, de, co,s,la)),
               columns =['Repository title', 'Repository description ', 'Contributors count','Stars','Language'])

# %%
p
# Out:
#                                  Repository title  \
# 0                           toeverything / AFFiNE
# 1                                    utmapp / UTM
# 2                   NVIDIAGameWorks / kaolin-wisp
# 3                            microsoft / terminal
# 4                              jina-ai / discoart
# 5                          martinshkreli / models
# 6                       facebookresearch / ParlAI
# 7                         KalleHallden / exer_log
# 8      juliocesarfort / public-pentesting-reports
# 9        EbookFoundation / free-programming-books
# 10                              moyix / fauxpilot
# 11  josejesusguzman / acordeon-az500-innoovaccion
# 12                          adiwajshing / Baileys
# 13                             qmk / qmk_firmware
# 14                      valinet / ExplorerPatcher
# 15                PKUFlyingPig / cs-self-learning
# 16                    lucidrains / imagen-pytorch
# 17                         Womsxd / AutoMihoyoBBS
# ...

# %% [markdown]
# # 6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https:/www.billboard.com/ '
driver.get(url)
time.sleep(2)

# %%
t=driver.find_elements(By.XPATH,'/html/body/div[3]/header/div[2]/div/nav/ul/li[1]/a')
t[0].click()
time.sleep(1)

# %%
# Scapping the information in the list
p=driver.find_elements(By.XPATH,'//div [@class="chart-results-list // lrv-u-padding-t-150 lrv-u-padding-t-050@mobile-max"]')

# %%
y=p[0].text.split('\n')

# %%
c=y[6:415]

# %%
c
# Out:
# ['1',
#  'About Damn Time',
#  'Lizzo',
#  '1',
#  '1',
#  '15',
#  '2',
#  'As It Was',
#  'Harry Styles',
#  '2',
#  '1',
#  '17',
#  '3',
#  'Running Up That Hill (A Deal With God)',
#  'Kate Bush',
#  '3',
#  '3',
#  '29',
#  '4',
#  'First Class',
#  'Jack Harlow',
#  '4',
#  '1',
#  '16',
#  '5',
#  'Wait For U',
#  'Future Featuring Drake & Tems',
#  '5',
#  '1',
#  '13',
#  '6',
#  'Break My Soul',
#  'Beyonce',
#  '7',
#  '6',
#  '6',
#  '7',
#  'Late Night Talking',
#  'Harry Styles',
#  '9',
#  '4',
#  '10',
#  '8',
#  'Me Porto Bonito',
#  'Bad Bunny & Chencho Corleone',
#  '6',
#  '6',
#  '12',
#  '9',
#  'I Like You (A Happier Song)',
#  'Post Malone Featuring Doja Cat',
#  '12',
#  '9',
#  '8',
#  '10',
#  'Heat Waves',
#  'Glass Animals',
#  '8',
#  '1',
#  '80',
#  '11',
#  'Bad Habit',
#  'Steve Lacy',
#  '14',
#  '11',
#  '4',
#  '12',
#  'Sunroof',
#  'Nicky Youre & dazy',
#  '16',
#  '12',
#  '9',
#  '13',
#  'Big Energy',
#  'Latto',
#  '11',
#  '3',
#  '40',
# ...

# %%
# Scraping the information from the website and storging in the list
ra=[]
sn=[]
al=[]
lw=[]
pr=[]
wc=[]
for i in range (0,52):
    ra.append(c[(i*6)])
    sn.append(c[(i*6)+1])
    al.append(c[(i*6)+2])
    lw.append(c[(i*6)+3])
    pr.append(c[(i*6)+4])
    wc.append(c[(i*6)+5])

# %%
# Buliding Dataset using scrapped information
z= pd.DataFrame(list(zip(ra,sn,al,lw,pr,wc)),
               columns =['Rank', 'Song name', 'Album', 'Last week rank','Previous rank','Weeks on board'])

# %%
z
# Out:
#    Rank                               Song name  \
# 0     1                         About Damn Time
# 1     2                               As It Was
# 2     3  Running Up That Hill (A Deal With God)
# 3     4                             First Class
# 4     5                              Wait For U
# 5     6                           Break My Soul
# 6     7                      Late Night Talking
# 7     8                         Me Porto Bonito
# 8     9             I Like You (A Happier Song)
# 9    10                              Heat Waves
# 10   11                               Bad Habit
# 11   12                                 Sunroof
# 12   13                              Big Energy
# 13   14                           Wasted On You
# 14   15                             Jimmy Cooks
# 15   16                        Titi Me Pregunto
# 16   17                The Kind Of Love We Make
# 17   18                                    Stay
# ...

# %% [markdown]
# # 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/hr-recruiters-consultants
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https://www.naukri.com/hr-recruiters-consultants '
driver.get(url)
time.sleep(2)

# %%
# Getting to the webpage
w=driver.find_elements(By.XPATH,'/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input')

# %%
w[0].send_keys(' Data science ')

# %%
e=driver.find_elements(By.XPATH,'/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button')
e[0].click()

# %%
# Scapping the information in the list
j=driver.find_elements(By.XPATH,'//span[@class="fl ellipsis"]')
d=driver.find_elements(By.XPATH,'//span[@class="ellipsis clr"]')
s=driver.find_elements(By.XPATH,'//p[@class="highlightable"]')
u=driver.find_elements(By.XPATH,'//div [@class="hireSec highlightable"]')

# %%
na=[]
de=[]
co=[]
sk=[]
lo=[]
for i in range (0,50):
    na.append(j[i].text)
    de.append(d[i].text)
    co.append(s[i].text.split('\n')[-2])
    sk.append(u[i].text)
    lo.append(s[i].text.split('\n')[-1])

# %%
# Buliding Dataset using scrapped information
w= pd.DataFrame(list(zip(na,de,co,sk,lo)),
               columns =['Name', 'Designation', 'Company', 'Skill','Location'])

# %%
w
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                             Vaishnavi Kudalkar
# 11                                 Priyanka Akiri
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                             Mahesh Babu Channa
# 16                                   Kapil Devang
# 17                                Sakshi Chhikara
# ...

# %% [markdown]
# # 8. Scrape the details of Highest selling novels.
# URL = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare '
driver.get(url)
time.sleep(2)

# %%
# Getting to the webpage
m=driver.find_elements(By.XPATH,'//td [@class="left"]')

# %%
g=driver.find_elements(By.XPATH,'//td [@class="last left"]')
# Out:
# '2'

# %%
# Scapping the information in the list
ra=[]
ti=[]
au=[]
v=[]
pu=[]
re=[]
for i in range (0,100):
    ra.append(m[(i*5)].text)
    ti.append(m[(i*5)+1].text)
    au.append(m[(i*5)+2].text)
    v.append(m[(i*5)+3].text)
    pu.append(m[(i*5)+4].text)
    re.append(g[i].text)

# %%
# Buliding Dataset using scrapped information
l= pd.DataFrame(list(zip(ra,ti,au,v,pu,re)),
               columns =['Rank', 'Book Name', 'Author name', 'Volume Sold','Publisher','Genre'])

# %%
l
# Out:
#    Rank                                          Book Name       Author name  \
# 0     1                                  Da Vinci Code,The        Brown, Dan
# 1     2               Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2     3           Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3     4          Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4     5                               Fifty Shades of Grey      James, E. L.
# ..  ...                                                ...               ...
# 95   96                                          Ghost,The    Harris, Robert
# 96   97                     Happy Days with the Naked Chef     Oliver, Jamie
# 97   98              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98   99  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  100  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
# ...

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= ' https://www.imdb.com/list/ls095964455/'
driver.get(url)
time.sleep(2)

# %%
d=driver.find_elements(By.XPATH,'//span [@class="lister-item-index unbold text-primary"]')
y=driver.find_elements(By.XPATH,'//span [@class="lister-item-year text-muted unbold"]')
g=driver.find_elements(By.XPATH,'//span [@class="genre"]')
r=driver.find_elements(By.XPATH,'//span [@class="runtime"]')
rt=driver.find_elements(By.XPATH,'//body/div[2]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]//div[2]/div[1]/div[1]/span[2]')
n=driver.find_elements(By.XPATH,'//body/div[2]/div/div[2]/div[3]/div[1]/div/div[3]/div[3]//div[2]/h3/a')

# %%
# Scapping the information in the list
ra=[]
na=[]
ye=[]
ge=[]
ru=[]
for i in range(0,99):
    ra.append(d[i].text)
    na.append(n[i].text)
    ye.append(y[i].text)
    ge.append(g[i].text)
    ru.append(r[i].text)

# %%
rat=[]
for i in range(0,99):
    rat.append(rt[i*2].text)

# %%
v=driver.find_elements(By.XPATH,'//div [@class="lister-item-content"]')

# %%
t=[]
for i in range(0,99):
    t.append(v[i].text.split('\n')[6])

# %%
vo=[]
for i in range(0,99):
    vo.append(t[i].split()[-1])

# %%
# Buliding Dataset using scrapped information
j= pd.DataFrame(list(zip(ra,na,ye,ge,ru,rat,vo)),
               columns =['Rank', 'Name', 'Year', 'Genre','Run time','Rating','Vote'])

# %%
j
# Out:
#    Rank                            Name         Year  \
# 0    1.                 Game of Thrones  (2011–2019)
# 1    2.                 Stranger Things     (2016– )
# 2    3.                The Walking Dead  (2010–2022)
# 3    4.                  13 Reasons Why  (2017–2020)
# 4    5.                         The 100  (2014–2020)
# ..  ...                             ...          ...
# 94  95.                         iZombie  (2015–2019)
# 95  96.                           Reign  (2013–2017)
# 96  97.  A Series of Unfortunate Events  (2017–2019)
# 97  98.                  Criminal Minds  (2005–2020)
# 98  99.           Scream: The TV Series  (2015–2019)
#
#                        Genre Run time Rating       Vote
# 0   Action, Adventure, Drama   57 min    9.2  2,018,335
# 1     Drama, Fantasy, Horror   51 min    8.7  1,112,126
# 2    Drama, Horror, Thriller   44 min    8.2    958,564
# 3   Drama, Mystery, Thriller   60 min    7.5    286,588
# ...

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
# Connecting to the browser
driver=webdriver.Chrome(r'C:\Users\Vishal Manoj\Downloads\Chrome\chromedriver.exe')

# %%
# Connecting to the webpage
url= 'https://archive.ics.uci.edu/'
driver.get(url)
time.sleep(2)

# %%
# Getting to the webpage
t=driver.find_elements(By.XPATH,'/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b')

# %%
t[0].click()

# %%
# Scapping the information in the list

# %%
y=driver.find_elements(By.XPATH,'//body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr//tbody//p')

# %%
u=driver.find_elements(By.XPATH,'//body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p')

# %%
w=driver.find_elements(By.XPATH,'//body/table[2]/tbody/tr/td[2]/table[2]/tbody//td[3]/p')

# %%
e=driver.find_elements(By.XPATH,'//body/table[2]/tbody/tr/td[2]/table[2]/tbody//td[4]/p')

# %%
v=driver.find_elements(By.XPATH,'/html//table[2]/tbody/tr/td[2]/table[2]/tbody//td[5]/p')

# %%
m=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody//td[6]/p')
k=driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody//td[7]/p')

# %%
dn=[]
for i in range(0,622):
    dn.append(y[i].text)

# %%
dt=[]
t=[]
at=[]
ni=[]
na=[]
ye=[]
for i in range(1,623):
    dt.append(u[i].text)
    t.append(w[i].text)
    at.append(e[i].text)
    ni.append(v[i].text)
    na.append(m[i].text)
    ye.append(k[i].text)

# %%
# Buliding Dataset using scrapped information
j= pd.DataFrame(list(zip(dn,dt,t,at,ni,na,ye)),
               columns =['Dataset name', 'Data type', 'Task', 'Attribute type', 'No of instances', 'No of attribute','Year'])

# %%
j
# Out:
#                                           Dataset name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...
